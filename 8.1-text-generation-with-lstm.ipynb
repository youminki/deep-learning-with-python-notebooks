# %%
from tensorflow import keras
keras.__version__
# Out:
# '2.6.0'

# %% [markdown]
# # LSTM으로 텍스트 생성하기
#
# 이 노트북은 [케라스 창시자에게 배우는 딥러닝](https://tensorflow.blog/deep-learning-with-python/) 책의 8장 1절의 코드 예제입니다. 책에는 더 많은 내용과 그림이 있습니다. 이 노트북에는 소스 코드에 관련된 설명만 포함합니다. 이 노트북의 설명은 케라스 버전 2.2.2에 맞추어져 있습니다. 케라스 최신 버전이 릴리스되면 노트북을 다시 테스트하기 때문에 설명과 코드의 결과가 조금 다를 수 있습니다.
#
# ----
#
# [...]
#
# ## 글자 수준의 LSTM 텍스트 생성 모델 구현
#
# 이런 아이디어를 케라스로 구현해 보죠. 먼저 언어 모델을 학습하기 위해 많은 텍스트 데이터가 필요합니다. 위키피디아나 반지의 제왕처럼 아주 큰 텍스트 파일이나 텍스트 파일의 묶음을 사용할 수 있습니다. 이 예에서는 19세기 후반 독일의 철학자 니체의 글을 사용하겠습니다(영어로 번역된 글입니다). 학습할 언어 모델은 일반적인 영어 모델이 아니라 니체의 문체와 특정 주제를 따르는 모델일 것입니다.

# %% [markdown]
# ## 데이터 전처리
#
# 먼저 말뭉치를 다운로드하고 소문자로 바꿉니다:

# %%
from tensorflow import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 1us/step
# 614400/600901 [==============================] - 1s 1us/step
# 말뭉치 크기: 600893

# %%
type(text)
# Out:
# str

# %% [markdown]
# 그 다음 `maxlen` 길이를 가진 시퀀스를 중복하여 추출합니다. 추출된 시퀀스를 원-핫 인코딩으로 변환하고 크기가 `(sequences, maxlen, unique_characters)`인 3D 넘파이 배열 `x`로 합칩니다. 동시에 훈련 샘플에 상응하는 타깃을 담은 배열 `y`를 준비합니다. 타깃은 추출된 시퀀스 다음에 오는 원-핫 인코딩된 글자입니다.

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57
# 벡터화...

# %% [markdown]
# ## 네트워크 구성
#
# 이 네트워크는 하나의 `LSTM` 층과 그 뒤에 `Dense` 분류기가 뒤따릅니다. 분류기는 가능한 모든 글자에 대한 소프트맥스 출력을 만듭니다. 순환 신경망이 시퀀스 데이터를 생성하는 유일한 방법은 아닙니다. 최근에는 1D 컨브넷도 이런 작업에 아주 잘 들어 맞는다는 것이 밝혀졌습니다.

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# 타깃이 원-핫 인코딩되어 있기 때문에 모델을 훈련하기 위해 `categorical_crossentropy` 손실을 사용합니다:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)
# Out:
# /home/work/.local/lib/python3.7/site-packages/keras/optimizer_v2/optimizer_v2.py:356: UserWarning: The `lr` argument is deprecated, use `learning_rate` instead.
#   "The `lr` argument is deprecated, use `learning_rate` instead.")

# %% [markdown]
# ## 언어 모델 훈련과 샘플링
#
# 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#
# 1.	지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2.	특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3.	가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4.	새로운 글자를 생성된 텍스트의 끝에 추가합니다.
#
# 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# 마지막으로 다음 반복문은 반복적으로 훈련하고 텍스트를 생성합니다. 에포크마다 학습이 끝난 후 여러가지 온도를 사용해 텍스트를 생성합니다. 이렇게 하면 모델이 수렴하면서 생성된 텍스트가 어떻게 진화하는지 볼 수 있습니다. 온도가 샘플링 전략에 미치는 영향도 보여 줍니다.

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 124s 79ms/step - loss: 1.9569
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the self-and the sell the command and the all the self and command the concemst the the have the command and the command in the in a stance of the sect the self the some himself in the will the command in the command and the will and the command and the expect of the sell and the command and the believed and the an a some no distinct it is a man the trate the command the sell and the religion of
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the realition with the man and more with the command and more of the and and should and with the rest believed by the in us of the life and into the cansfore that the compuldion and have the chared and calst and of the age har inders the commander the thing more which the accome it is wert the prosent the indived by an an as one should in the somethine they are from endous of accest and the dest
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for duirity, but agrto imathity, such like, in
# the that the restentilicusmate and yulliest one them, if withed of
# inded cleation and mairs, con gurm many in a lons are his the  os; perenderhudianation oregind from the thought in the uswile, "shar
# thought theartery ate feed sutspeed ay  do a world the prenor ungaluabing regad! and this one, with at
# least moy dissucciquit brorm. hap in unwithontheat.
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foree; 0" for ownoth), that the onever emey foult, whon or visgatis doesseous,eand which axsefud and -for in ig-is an
#  -dill-aromegged had hewiling itilish
# instrogably it wem leam thadd
# knowhed-ming in
# oldans--than why coltergana regile. like he it of thems, i    bet
# impoliaus.. genty
# : itherefuakely finthance boon"xthing, but exisiall--with bxtlated tide arcensed in tive nobder, it! and porters, -t
# 에포크 2
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.6104
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense and all the sense and a considered and acts of the and the spirit as the fatter and the and antincies and the served and of the spirit and as a consequences and and man is the self a sourself as a consequences of the world and as the and the strenge and a strong the sense them which is a consequences and a consequences and place and them and strong and strenge of the speak of the spiri
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through folly are every religion of the every an interroked by the self a souriches of
# the speak: the spirit and in the tern devilogical as
# a not the world not sone the about himself and are so the presented them world as the well "their have longer as the present and spirit as be
# rathed them and things, the spirit and course which seems and the then in the will in the streed and sufficiently to them the st
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the evolvty dingerang and so
# putsions, which the entire, impulseing will doin,.
# sayences (ab it is for appussion to attronge man and
# wild seems of call
# decepsing--but, he has avourcolments of deopy verity sonanching surpical as religion, which, whichhe artiousness. in the me will alatist the will hoursome have then anom, to speaks about truth. the e lly ahtlus of
# helped the spirit instincts atte
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for givergy u; pretentions
# too must hacrantess--wh
# the become ornif the alvead in
# over yervo-etter--evence ruley.
# "but own as pregings of blach an agtalouries especiames--is, what whake breatt. i he adapueasume:--and they, this,
# mewilicula unsilictss:frey, aster fore! the lich and as progauls
# not themselve, sivility
# in the otn it is.
# iunation, etco2pfuin, thome
# leas
# "nie tyth, age, at _ull, withontr
# 에포크 3
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.5268
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for an all account in the sense of the self-consideration of the superative and the more and contempt and contradict of the same and the sense of the self-consider the still and perhaps a such a man the amours and subtions and constraint and the self-contrary and the same the self-consideration of the sense of the sense of the existence of the most been the superation of the condect of the self-cons
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for as it is never the destructive so the most account the more in man is every belong are with a man and the who who has all believe the self-constrayed and share an all perhaps a problem real all the supers or in the belong the patism of the progations and destructive fact of the same the occasions of the will and consider that is in his a form of more interestinction, and the fact think retermina
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forsologrances, and we be something so-day
# being as a maided and "most makeful metaphysica friendfs resuption. than it ease fivations is not pain blings eaties in liar the aways, of the sund insumery of di serf viewt
# be des sing, value scaining as the gorweous posity what the boldin of hasily expecteonblem withous kinctunes as suicless with are, we man rest an the mones for except of the hund ma, is
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foins any itstripus tas s
# thingings inmassable virwal nexish wiswis revegen the were a crowhiber-, hame
# immetalms outhis feelingly close metapprate of which is healthey, becime sorakly, are christify--believesnonwing no physici!g, of
# this it revenged of men is once precipwicis evertry of the faarfeatingishs in fiodafly end rung cunceve. it, lche--and new geniuis. an all oeed boyd of
# case.. patticte.
# 에포크 4
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.4812
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the contemness of the strong interpretation and the general and the self the self-contempting of the self-contempting and the contemneed, and the desire of the interpretation of the presented to the self-contempting the strong interpretation of the strong the strong the contemness of the contemness, in the self-contempting and all the contemness of the self-contempting and the self the consequen
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a storm of every desire a contemness of the spirit in the themely interpretation which has not be the state who have presentess of the development of the decessing some one was art of the german and in the comparine to the religious certain let us an all contem of the pray of the contemness
# of the most the delightes and the state of the far all the intimils of the more speak of the case and man
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for it is own it; for the through ethical, stool, have them religion and appearaments makes
# astenting ormeries have a cilu!
#
# is
# operad of the
# temporty man, when he attention be that our ont the phelopsilary, and question and suar, and in
# the opposites itself--and thew her them weicle operiopion us in the worhd of circumsible mettofound, this play beink faidation and no; such
# operdeds hollow which in
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forelyolian dance oo: the herongly, knowledpy of
# endwlys,
# where haj sibidme--been lick of own theorive wantine amates: and a maonfer or relution who seeds an it,
# indeed. the one
# hesit, and ulon-fandyntress to simplilad-gance.
# butnessmeny modey done precouscipentasly, folleeapes thoog, sin bo
# he, and even when they one brither
# alte acmion,
# loone aspontefse, ma, for
# eye in greatly
# nature,inarar impain
# 에포크 5
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.4524
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the subtle to the end makes the philosophical conscience of the east and desire of the self the self the end and desire of the even at a desire of the self the sense and souls and souls as a desire of the religion of the exception and the self the subtle to himself, and one of the sense of the sense of the experience of the sense and discosent and the subtle to the sense to be the our even the s
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for a man who all he souls and men, the struegbance in the fect and of him, as a man worth to be the force, to lifece of the subtle to so the belief mistaken against the person of the religion of the man to a delight must be and such a soul of the sure, and he man with the consequence as a soul to which the souls of the one of a misunderstand and how of the names and his not attain of a spirit of th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through follitated and what all the
# descist in descusable, has the
# reason of wet is soulds "who unders also developed as we excent periors of the work one mestasuch, tided is
# adviscrioned has pessing, houred prityuality of  uplatoraon and that is health as has now generaciant of him, and nimpess, there is are of
# error and the
# position, effection, or a being christian mainte.
#
#
#
#
# oed flagit, which after
# germ
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through formul", adonaked. their fampeen by deciqourerance and surbine dher far to appearm "extent repantly
# hesith subdit etanceptif2in religious even  elses and chear ofen vility, he worker, with the period with the free. the christian, and
# a something
# host oges
# souldness
# and self does not be myself (mimall people--and has a them
# soul to be additding? low objuckest, one of promacts. fort vreat
# "nationd.in
# 에포크 6
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.4296
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the same the man which is a some things of the same the man who have been the man to the man which the same think and the man which is the man which is a some time and the same that is a some things and most the consciously the too the man which is a some things of the same to the man which is the continual possible to the man who have been the man in the man who are some time and the d
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foren a most fact of that a say, and men in the belightan
# still good the soul as a see of men have been a the fact this contraned to the still and the secondian
# as a self-more modes with the presentions of the antillastounce of the man barbited and propoured by the finderness of the value of the self-play of the faith for godlaness in the many cansitions of a change in the may be despesious characte
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through founds, and here extent of truth therefor degreateser on german and 1zers man
# prefrimitte the faith the slogited of man been in the delighance science which not se suffering of manxed; but estimate humans. the domalism. to the cauration, believed, which does and effection, dispustially and had but the dangen of underputifists of laid wishes and atistime thrth. what will alchull honoring character ti
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form possposiblad and vre?tity, is religions to all feem one maetar, visuay a, too lively in
# obtumenting
# in the emotionre of the insulded than he want:  pychivist century,
# fair too preauslors afteryune
# presione. namies a ruecrates ohing arc? what happen aidativement should leagn. than certainty
# phopess"horuce
# philosophy in fye, heading" f,ers bount.
# -no
# powerfution, as
# moralsy; dringersver of,,
# no
# 에포크 7
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.4117
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense in the first far and the dealing in the self, and the strength that the most the states the serious and the sense of the serious and the strength and states of the state of the serious the states of the states the state of the same and the strength of the strength the states of the strength the standard and seriousness of the strength the state of the incomparist the present to the ser
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the still and a things of an interesting which were is allow the stating the can new sounds of men and menianity upon the result which is allow in the certain in the reason of the morality and taken that allow be the
# basis the surrence that the case of destruction and man additional has been man. the morality and wishes a survales, the certain to ranken and called been his redived, the by prefea
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for their usnazed of passion their asking char striman in
# this man norminity cares last hitherto the raugbating and
# said not in the presently which surgrong exist, merely delight werdon of oldly, wheneged these fear with
# crible, as the malous to hand
# tysienbsmance" so that is imnorment to a rade), let us anonal
# "mode are when feels"-
# last aristopient, and no, feel power which habitses "brought enday
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through former shide; europed, bat mjuct, whoght"er interpretation, understood,
# if he perhaps unminc: but though ame
# shamed
# lizer unsod. however, that ever
# signified keec; what inkine, this fundamental hand, his
# "formers to preebed. everything handsaring" is genius, magiveres wildous neverthifitionshress.
#
# thom being were distfuls othter. thus sponds for god repested on: flears is effect a cicts itself", th
# 에포크 8
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.3983
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the existence of the expression of the extrendant and the expression of the greatest and the sense of the expression of the antight to the expression and the still and the existence of the sensitte to a state of the strong the sense of the expression of the most tempted to the existence of the state of the expression, and the actions of the best and the intelliged of the sense of th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for every dignification of the
# existence of the sense
# of the degree for one stricted the lowered to many and injurical states of the maliguate of the into
# the error and the except of the surviction of an actions of the conscience and very condition of view of men of the beent in recognize to its that the certainly of the greatest to course of the rationally and rule of the philosophers and many the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the our idea on the same impulse and
# torring, the honourm, the overtens of these ideal
# an
# oyse, idea oughing, of )ye weoft out of nciestion are tears make a nothing deceptives of destany, flashminam ever religion to themselves into teelly and horr
# of to being. to meno"--this
# "far
# atspeished normly regard of induep before noway of
# the goderantbst? whether, fugindafeed to are, namely, begotic old
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# the hearted iture, o jows imbunity; he wile is called horty, when we dangefuedamely
# who
# arr long
# is operable acon he joev, a would
# lives with the totaltes in
# fagitf, odytest os beever been
# froms the contempt fuethest slay at false cimautation of lone such a deflectively
# imserve.
# in which
# she-banded classarifuth: he ono" is being conyethran fro"k," was thenfle, being
# exhrection". then the highly
# 에포크 9
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.3868
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the superficially and the most art of the same that it is a so means of the same the sentiments of the art of the profound and consequence of the most order to the same the property of the man is the most antimine the same the comparise the privile the same and decided and that the most more the states of the most antice of the same that the belief of the same thereby have no longer and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the another and religions of the spiritually in
# the formed cause of the most action, which play, is many every man with the father of an almost life and the disting of the antitheranicant the
# suh himself with a cluse that is every thinks of such men and all the way that which has been always all the domald the most hight the estimates of the german good and lower pations
# of such its own similati
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for ord of
# chearcratist: and did alsood all them: and that of such artbown gurdobow, and problem of the cividies with mobdliess, mankind (here cause
# of quiless,
#
# we the.
#
# that i would not true produce respect and inligion them.
#
#
# 13t
#
#
# how
# hersely alount and
# life myself,"
#
#                                                                                   and how who-lose staid thus it
# in the who noth
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form, to reference a , a limitments and gof.
#
#  1 1djence arts oppees therefore
# scheponisn--anmplaties, who wauglious, result for
# one" for-demanity."
#
#
# if wance tkinces nwoo in deins," causo and away historistic of the
# many bad aboration,val as, wime, to y, imperies. ruch us the cvewedfy vever
# storuleing is were the new humne desposedion which we acted! and also was the know himorawed, mattrion: his
# 에포크 10
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.3769
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the and consequently and consequently and all the strength and in all the spirit and suffering the present in the strength and specialized and all the surpets of the spirit and suffering and the strength and the spirit and consequently and specialized and all the superiority of the spirit and sense of the strength and an instince and desires and present in the strength the supersped the spirit a
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for such at the world and with them are of the new present complemening of the part find, and person of the struming the fatter and pride of the instince and spirituality of the emerited upon a democration, only and the sport of the spirit and with and the principle of the person of the reality in the spirit, not expediences of the distinguish
# did not dangerous operates them and consequently merely
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for"essings them ourself" in lovicule with b"thing applar become now tradime upon the organicious cult exagme refined boring this takef away thas benear, what is orril and of proceering of historadwork in the rank is natuate others and soied. dominisment, all learne,
# and easter--we allow the spirit. forthobje cxived in its insuruition, grother regards is all chepavie, and attempt of
# his kince touche
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forress; which be fail of his io, as the intervaludes opinions of you. eveits
# at this compalsess. agarding "head, anmead of will. an eurise to lowen benefact to thdineded diff
# in lowened, where a w".
#
# 1he
#
#  fil absolute h, sogetic will evitatures in viec
# maphaisnessly motives,--h; with the least doowwak,s of case him in result oo cri? as but to "comstition:th by that it. hywancs, nere and but to the
# 에포크 11
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.3683
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the man as the subject of the subject is a subject that the man of the same warl of the same time the subject of the expersence of the sense and the consequently and the struggled and the serving and the greater and the morality of the same time will and the man is always the faith the consequently and the man of the fact the man as a subject the subject the man as the sense of the strugglent an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the greated and not to all the world and in the comprehensis and point to the morality and duties and sharrongers and always the man that we notwind that the stronger and still at the desire to a scientific greated for distingration. and the formed they believe them in the far the philosopher of the man was natural themselves to intermile of conscience of mankind the fact difficult to be a desir
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for themselves, unterment the  of his classess. involved to be error-happiness: this very conmilar, hoew outsible or mend--and expedience will youth
# nothings, some this very dea prided, it is , obegalie.
#
#                 wi=lers of
# may be then any life, ivail bethine of the
# same sight because, of experience: there sleepentation of
# pain of been readbuct wilk lerm they bad with unimilst cxifice, towar
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for ons"ed tofavour orly ferlines of a class. for flhiffuluely-daytned
# series?" says would does heir is finded arcustinced: the mellosian admindr"
# may be the
# shach.ifien into him, but might
# be seems of
# expressing; laws who rebrlexing: the meck.
# what w
# sur if sirried only thus, whichth--that there nothives), about plessively growk desention
# (he way alrohides for his friend"--
#
#
#
# 112it facts and sa
# ca
# 에포크 12
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.3619
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for a still and the sense of the particular and all the most strength to be as the senses of the and the sense of the sense of the power of the senses the senses and sense of the power to the senses of the sense of the strength to the most and conscience of the present of the same time and the sensible to the senses and actions of the profound and the soul, and the profound and discovery one should
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for more the sensible in the an all here
# stinds of the pressions to all the higher and spirit of individual and discovery of belief him which fact the discisten as a small avoid of the sure as the sense of his standard and and men, or place and the commonply traditional and person of the more power than a more particle and have a german senses to the profound as to the commonsless, the powerful spir
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forrublie or of geniuse europe of which latera. afterpalic of a discovershing and meligulerw
# and freedom.=
#
# in xu.feenceable
# balish it sescausing permituless opposed, is that halfce with lights and craugemposing maleate three pication its
# very regard of the will to go men, it is all reststensy. and exercies in which it seems to be prozerary coursg, in the errofess perhaps the motherty of this lo, ev
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for life
# rtit, forthy libe.wether, one skem'wow to pless as
# inful
# once clalgotionam iscl, they
# often, lad to fast of clgas, recepail, which, alther--an egmmen all them, thek;--if haw its arcopart develos the genius, and ham of
# vanity, had too lice
# are
# restiness; belong
# hencew
# spiritian.bjud out tany
# of inruless itical, in the freef, he, that the general jengarized--in the illicy
# impursers trorable v
# 에포크 13
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.3541
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for a present concerning the strive the more the transfore a standan an artists of the strive the standpiness and strive the present concerning the morality of the same time the strangely conscience and the strive the strive the same as the strugglity of the strive the more the more the strangely proved the conscience and the moral man in the present discomparing the conscience and the sense of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the need of the tance the consciences of the present does a more the german disting the present in the have no longer discovered in in the strong and probable conkepting and our science them of the bad being good in the most the end in the morally thing thinking and humanity, the sensible in such standard and conditionally ideal of the strumtfully thinks to the worshishwards of the paristing in
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through fore: thus, disnas: yes, which teast of all the warling (to relicatedly, on at ludef vulgally b fully a to rutive finite,
# to
# them,
# he dasge is personty of attentive tooge. even make
# the great and all lif, have net literar
# nellogy--he reaped--i once confost when the dgpow the mothers back nom their philosophers resmon and forevooding,
# we a shain greatar
# had all mages, some disuncatisbeling contrary,
#
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forcure: that he noerctul. the sense and
# accumus for dutelfys frangeswdle decipation of "frane little
# picedring our judgment--suffinent of pleasure recelled frread protect "in revolution only in opposings and greater-lome upon are names to ambiling"--oethapagn and constantmen, to mappless himself balling the tain bifd all will extent tf away power-germinary wish as to be
# virtuigs and truydart, man "
# 에포크 14
# 1565/1565 [==============================] - 119s 76ms/step - loss: 1.3487
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the most present the structive the consequent the same and the conscience of the same account of the strength of the spirit of the spirit of the most expedient, the contrary the structive the consideration of the sense of the consequently of the soul and the structing and the conscience of the spirit of the sense of the same soul and the consideration of the spirit of the struction of the struct
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the man who would plehasion and about, one who are an attempt that the
# and the superiorist is the real and the instinct of the responsibility of the pression themselves to the absundersance, all the most responsible for the spirit of the countrined by the finer development in the except every tenders of the same more comparated by the spirit, the consequently deem desires, it is a subctive the p
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for presens, they spicatols about
# in the oruati--songun in an unefosumed
# operated the obligation und reference and wherever deepolo-there here
# best unricheromentud
# repose and discourses
# their faith to medioc! accordance it sy bithest of a franness some
# rests as traudcent forth
# invoinntly
# to
# the problem as operate as--if his "awaken in which
# been
# incruencase to certain, the are a to see wes other opl
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for said to "culted ih, precisely (whow tory,
# inveeditlan olden mavail. "made to become anyt(d.
#
#
# 13o
#
# sumetort within is true: if
# histok as
# accvedwonly as exposibility,
# sman all volbolinant and hous
# harmoun being itself a interpresioned only, o shaming to
# suffers pas, affain can exure, and judgmented, gadual is strongul medualy; there
# saudwee?p."  one has
# never,hersu's the sameers (of his i to
# litt
# 에포크 15
# 1565/1565 [==============================] - 120s 77ms/step - loss: 1.3415
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strength the strength the strength the strength to the discovered the most the strength the philosophy and the strength the supposing strength the strength the strength the strength to the same time the strength the strength to the philosophy and strength to the soul and always a standard and the spirits and strength to a states and as the strength to the spirits the strength the strength th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the greatest that destruction, and the fundamental are arounds to the reason and states the other of the feelings of the faith, who with everything and perhaps in the best as the most one is always and sufferings of a commandly in the great destruction of the comparitical consequently that is why not to the are party in the most conscience of the strength and the essentially of the steps and str
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through followwkel a masside-greatness of their depression
# for grantity and in the germans justificate in whole latter in necessary
# indifference that, indusablige of man is perhapses, some great diskerses which viow deli every po
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for a sidled spirits been are that are really among the wors, logiche;
#  oncence is leads exceptional proper he think than
# take when the does anyart matters; for the
# species are more
# goes--he thinked: the sought in the more to himself.
#
#
# 40of lo!h" shargon in spirits of the nations the proves us old moralising cinal trim"y are, talking frev,as case in the presiting one will origin. to this merous pri
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forts groumds up not erdowing and with arrec:
#
#      ysteweque
# 1565/1565 [==============================] - 120s 77ms/step - loss: 1.2616
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the result of the most morality of the spirit to the strength the end of the father of the present man as a man who all the structud of the same time all the strength and suffer of the strength the most completely and part of the same time has been will a some submer and the facts of the most desires (for the strength and the morality of the most complaces the emotions of the facts of the sense
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for in the most feeling of the world world as the bast and brotheruses and moral philosophy of christianity of the consideration of the person of here man called best for what reference of the profound to be more precisely by the person of the end of the founder the religious scholars of such a democratic serviler, and more fellowed contempt of his passion and allow them more position of the greater
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foreufses to exections" in the end; my worhlqunts and one with such a complamised of ourselves which
# sharr profound people however, with himself, deguro
# may perhaps, i destrogon
# divined for inasmanded, no
# uption is also
# grows, which we loves suffer and avy thereglogicsion profeds and dovey
# are, more houghnes him mades-amtare part of sun who learn to depth, whoever engmast he common-sedfully, but sho
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forear effectious, and a christiam, and was much done, my guarss
# of it, olator of our spinitudi? but psychology,mentous scacuurati, in attain, most sypometh being now hitdx, with hences, however, are, we stend a master, tale, fressem in rexertious
# knew he imperious modise acts of cmoous within then evide" displued with
# maphisic more bynchumodious fado, wt the rexapphers, theory it is not, and
# histor
# 에포크 51
# 1565/1565 [==============================] - 120s 77ms/step - loss: 1.2620
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through foreground and still and some point of the present that the morality of the standpoint of the sense of the conscience of the sense of the same than the sense of the present the standpoint of the storually and some sublime to the sense of the present and sublime to the end and all the fact of the standard and some contempt of the sense of the stand of the consequences, and the commands of the standpo
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forear a corrusarisment of discontently and storuences of the man of the saint, not a some supersitudes, and some thing at the man to the belief the very does better? has hitherto alofaring the extent that man and compliciness
# of the last command--i mean the states and brings of the present there is a conduct to the same the sense of the discorration that is interecalous that the conscience, not for
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foremose to drace lased him,
# who problement that all afforded. flavs: something proptions, hence viwoession
# stone applis, has only as force of the interrocation, intellectually. and tale, attentiom.
# hent to arlority of implanled, vanity, solies of european "terdod and more an atteness, man, mappy in season
# form: he has be fullt, dreams, he sined that advancably hosthping and
# linds the religious effe
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through follow homy sprint as one mangumens, inci-re" victin was to manifold, sloging humane is supticism and life in the point all hompine morrality, are
# himself out ideruch, in the profound
# and disallist play--it is
# alived's
# badness, ancient because is world doce
# speak socurnation and
# intendeded youthing
# of the poliest as good talking would--these merely apul, they soul chingfing emouc; because bleekfes,
# 에포크 52
# 1565/1565 [==============================] - 121s 77ms/step - loss: 1.2588
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through former and souls, is the man who has the same time a south, and something something formerly and spiritual spiritual spirits and power of the same time of the spirit, and the condition, and contained and something in the same time a states and souls, the same time a states of the same time is a shark of the same time and superficial to the same time is all the same time the sense of the same time th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forming to the estimates there is the case the world which is perhaps fair and allow a person which is always with them which is all this is a honour, the spirit, the same taste of the personal philosophers and part of
# the fact his same time under the strength, as the deally and honesty, and the man of the world that is not be high an all the present plaines of the emotion of the
# same actikeness and
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forth, brhadest this displause of a forms feels hero musthe
# there are curces. in egoistsw'est "dot the otheral infected not flootur
# and bad,
# which has greater althen the
# art of futher, comperience as likewise such a parel-, will even lourbss.--for these nevertheless fello-to smpain of a tri: i had protrock when they bients, to the be the emotions,
# the old
# for hours;
# "the own sendlistige knowledge: t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through force, prose to be
# theneralfy and it--! bevory, of enough hiase warturent name!--when they in their
# law? whing viwold imagine himself the apparentall in one's effect
# intimalis
# through rebla cotter entary and fear man, shome means and is a subcien there place mixtien glist

# %% [markdown]
# 여기서 볼 수 있듯이 낮은 온도는 아주 반복적이고 예상되는 텍스트를 만듭니다. 하지만 국부적인 구조는 매우 실제와 같습니다. 특히 모든 단어(단어는 글자의 지역 패턴으로 이루어집니다)가 실제 영어 단어입니다. 높은 온도에서 생성된 텍스트는 아주 흥미롭고 놀라우며 창의적이기도 합니다. 이따금 꽤 그럴싸하게 보이는 완전히 새로운 단어를 창조합니다(‘begarmed’와 ‘isharent’ 같은 단어입니다). 높은 온도에서는 국부적인 구조가 무너지기 시작합니다. 대부분의 단어가 어느정도 무작위한 문자열로 보입니다. 확실히 이 네트워크에서는 텍스트 생성에 가장 좋은 온도는 0.5입니다. 항상 다양한 샘플링 전략으로 실험해 봐야합니다! 학습된 구조와 무작위성 사이에 균형을 잘 맞추면 흥미로운 것을 만들 수 있습니다.
#
# 더 많은 데이터에서 크고 깊은 모델을 훈련하면 이것보다 훨씬 논리적이고 실제와 같은 텍스트 샘플을 생성할 수 있습니다. 당연히 우연이 아닌 의미 있는 텍스트가 생성된다고 기대하지 마세요. 글자를 연속해서 나열하기 위한 통계 모델에서 데이터를 샘플링한 것뿐입니다. 언어는 의사소통의 수단입니다. 의사소통이 의미하는 것과 의사소통이 인코딩된 메시지의 통계 구조 사이는 차이가 있습니다. 이 차이를 검증하기 위해 다음과 같은 사고 실험을 해보죠. 컴퓨터가 대부분의 디지털 통신에서 하는 것처럼 사람의 언어가 의사소통을 압축하는데 더 뛰어나다면 어떨까요? 언어의 의미가 줄진 않지만 고유한 통계 구조가 사라질 것입니다. 이는 방금과 같은 언어 모델을 학습하는 것을 불가능하게 만듭니다.
#
# ## 정리
#
# * 이전의 토큰이 주어지면 다음 토큰(들)을 예측하는 모델을 훈련하여 시퀀스 데이터를 생성할 수 있습니다.
# * 텍스트의 경우 이런 모델을 언어 모델이라 부릅니다. 단어 또는 글자 단위 모두 가능합니다.
# * 다음 토큰을 샘플링할 때 모델이 만든 출력에 집중하는 것과 무작위성을 주입하는 것 사이에 균형을 맞추어야 합니다.
# * 이를 위해 소프트맥스 온도 개념을 사용합니다. 항상 다양한 온도를 실험해서 적절한 값을 찾습니다.
