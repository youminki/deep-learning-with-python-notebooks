# %%
from tensorflow import keras
keras.__version__
# Out:
# '2.4.0'

# %% [markdown]
# # LSTM으로 텍스트 생성하기
#
# 이 노트북은 [케라스 창시자에게 배우는 딥러닝](https://tensorflow.blog/deep-learning-with-python/) 책의 8장 1절의 코드 예제입니다. 책에는 더 많은 내용과 그림이 있습니다. 이 노트북에는 소스 코드에 관련된 설명만 포함합니다. 이 노트북의 설명은 케라스 버전 2.2.2에 맞추어져 있습니다. 케라스 최신 버전이 릴리스되면 노트북을 다시 테스트하기 때문에 설명과 코드의 결과가 조금 다를 수 있습니다.
#
# ----
#
# [...]
#
# ## 글자 수준의 LSTM 텍스트 생성 모델 구현
#
# 이런 아이디어를 케라스로 구현해 보죠. 먼저 언어 모델을 학습하기 위해 많은 텍스트 데이터가 필요합니다. 위키피디아나 반지의 제왕처럼 아주 큰 텍스트 파일이나 텍스트 파일의 묶음을 사용할 수 있습니다. 이 예에서는 19세기 후반 독일의 철학자 니체의 글을 사용하겠습니다(영어로 번역된 글입니다). 학습할 언어 모델은 일반적인 영어 모델이 아니라 니체의 문체와 특정 주제를 따르는 모델일 것입니다.

# %% [markdown]
# ## 데이터 전처리
#
# 먼저 말뭉치를 다운로드하고 소문자로 바꿉니다:

# %%
from tensorflow import keras
import numpy as np

path = keras.utils.get_file(
    'nietzsche.txt',
    origin='https://s3.amazonaws.com/text-datasets/nietzsche.txt')
text = open(path).read().lower()
print('말뭉치 크기:', len(text))
# Out:
# Downloading data from https://s3.amazonaws.com/text-datasets/nietzsche.txt
# 606208/600901 [==============================] - 1s 2us/step
# 말뭉치 크기: 600893

# %%
type(text)
# Out:
# str

# %% [markdown]
# 그 다음 `maxlen` 길이를 가진 시퀀스를 중복하여 추출합니다. 추출된 시퀀스를 원-핫 인코딩으로 변환하고 크기가 `(sequences, maxlen, unique_characters)`인 3D 넘파이 배열 `x`로 합칩니다. 동시에 훈련 샘플에 상응하는 타깃을 담은 배열 `y`를 준비합니다. 타깃은 추출된 시퀀스 다음에 오는 원-핫 인코딩된 글자입니다.

# %%
# 60개 글자로 된 시퀀스를 추출합니다.
maxlen = 60

# 세 글자씩 건너 뛰면서 새로운 시퀀스를 샘플링합니다.
step = 3

# 추출한 시퀀스를 담을 리스트
sentences = []

# 타깃(시퀀스 다음 글자)을 담을 리스트
next_chars = []

for i in range(0, len(text) - maxlen, step):
    sentences.append(text[i: i + maxlen])
    next_chars.append(text[i + maxlen])
print('시퀀스 개수:', len(sentences))

# 말뭉치에서 고유한 글자를 담은 리스트
chars = sorted(list(set(text)))
print('고유한 글자:', len(chars))
# chars 리스트에 있는 글자와 글자의 인덱스를 매핑한 딕셔너리
char_indices = dict((char, chars.index(char)) for char in chars)

# 글자를 원-핫 인코딩하여 0과 1의 이진 배열로 바꿉니다.
print('벡터화...')
x = np.zeros((len(sentences), maxlen, len(chars)), dtype=np.bool)
y = np.zeros((len(sentences), len(chars)), dtype=np.bool)
for i, sentence in enumerate(sentences):
    for t, char in enumerate(sentence):
        x[i, t, char_indices[char]] = 1
    y[i, char_indices[next_chars[i]]] = 1
# Out:
# 시퀀스 개수: 200278
# 고유한 글자: 57
# 벡터화...

# %% [markdown]
# ## 네트워크 구성
#
# 이 네트워크는 하나의 `LSTM` 층과 그 뒤에 `Dense` 분류기가 뒤따릅니다. 분류기는 가능한 모든 글자에 대한 소프트맥스 출력을 만듭니다. 순환 신경망이 시퀀스 데이터를 생성하는 유일한 방법은 아닙니다. 최근에는 1D 컨브넷도 이런 작업에 아주 잘 들어 맞는다는 것이 밝혀졌습니다.

# %%
from tensorflow.keras import layers

model = keras.models.Sequential()
model.add(layers.LSTM(128, input_shape=(maxlen, len(chars))))
model.add(layers.Dense(len(chars), activation='softmax'))

# %% [markdown]
# 타깃이 원-핫 인코딩되어 있기 때문에 모델을 훈련하기 위해 `categorical_crossentropy` 손실을 사용합니다:

# %%
optimizer = keras.optimizers.RMSprop(lr=0.01)
model.compile(loss='categorical_crossentropy', optimizer=optimizer)

# %% [markdown]
# ## 언어 모델 훈련과 샘플링
#
# 훈련된 모델과 시드로 쓰일 간단한 텍스트가 주어지면 다음과 같이 반복하여 새로운 텍스트를 생성할 수 있습니다.
#
# 1.	지금까지 생성된 텍스트를 주입하여 모델에서 다음 글자에 대한 확률 분포를 뽑습니다.
# 2.	특정 온도로 이 확률 분포의 가중치를 조정합니다.
# 3.	가중치가 조정된 분포에서 무작위로 새로운 글자를 샘플링합니다.
# 4.	새로운 글자를 생성된 텍스트의 끝에 추가합니다.
#
# 다음 코드는 모델에서 나온 원본 확률 분포의 가중치를 조정하고 새로운 글자의 인덱스를 추출합니다(샘플링 함수입니다):

# %%
def sample(preds, temperature=1.0):
    preds = np.asarray(preds).astype('float64')
    preds = np.log(preds) / temperature
    exp_preds = np.exp(preds)
    preds = exp_preds / np.sum(exp_preds)
    probas = np.random.multinomial(1, preds, 1)
    return np.argmax(probas)

# %% [markdown]
# 마지막으로 다음 반복문은 반복적으로 훈련하고 텍스트를 생성합니다. 에포크마다 학습이 끝난 후 여러가지 온도를 사용해 텍스트를 생성합니다. 이렇게 하면 모델이 수렴하면서 생성된 텍스트가 어떻게 진화하는지 볼 수 있습니다. 온도가 샘플링 전략에 미치는 영향도 보여 줍니다.

# %%
import random
import sys

random.seed(42)
start_index = random.randint(0, len(text) - maxlen - 1)

# 60 에포크 동안 모델을 훈련합니다
for epoch in range(1, 60):
    print('에포크', epoch)
    # 데이터에서 한 번만 반복해서 모델을 학습합니다
    model.fit(x, y, batch_size=128, epochs=1)

    # 무작위로 시드 텍스트를 선택합니다
    seed_text = text[start_index: start_index + maxlen]
    print('--- 시드 텍스트: "' + seed_text + '"')

    # 여러가지 샘플링 온도를 시도합니다
    for temperature in [0.2, 0.5, 1.0, 1.2]:
        print('------ 온도:', temperature)
        generated_text = seed_text
        sys.stdout.write(generated_text)

        # 시드 텍스트에서 시작해서 400개의 글자를 생성합니다
        for i in range(400):
            # 지금까지 생성된 글자를 원-핫 인코딩으로 바꿉니다
            sampled = np.zeros((1, maxlen, len(chars)))
            for t, char in enumerate(generated_text):
                sampled[0, t, char_indices[char]] = 1.

            # 다음 글자를 샘플링합니다
            preds = model.predict(sampled, verbose=0)[0]
            next_index = sample(preds, temperature)
            next_char = chars[next_index]

            generated_text += next_char
            generated_text = generated_text[1:]

            sys.stdout.write(next_char)
            sys.stdout.flush()
        print()
# Out:
# 에포크 1
# 1565/1565 [==============================] - 27s 15ms/step - loss: 2.2791
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the say, the condition of the ways the seem to the seem to be are in the say, the say, the say, the propess of the seem to be soul and and the seem to the same to become and the say, the faith and the seem and states the such the seem that he see of the seem to a man and proposition of the say, and in the say, that the such the same the sension of the faith the same that the sainter and soul and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for indeed instanct that be prifest to conscience in the condint to been for the from forman and procosed for also that the seem how interset of not to deary for the seaked the sables for the defice of the some the have in all not all the precessity of the same and the say, by the daimhtand morality and any found believes and is the suppocitions to possible and it his ving--whese more and noble, tha
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for must as
# snettly in the beenn of its
# in orjudi1 perhaps for (a stecting thus
# senses , an thitherse will ustit, they openomd come stath were
# friend of revilols she or onevilous vies precest edy if
# hat which beary provoused lood
# and
# an. syited mare,
# und--"homan sempatic and conde, anguthificass of orvious s all tempation
# the
# be. hithers old on hamone and so make
# the
# on!" is instingliary former that
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for lgregin and frict intention
# of this incept condition of his now: abown and hceven woll introseloly that discivel for hivtine, to "imal, "fheccorstices, discignt"--ots
# lunbalings for condempt con
# ating that eyi master,
# ry
# beforely codxiount ationt rimporasencess volain in a
# most but
# is grates.ful onestic brows cretate fraw, been long this alont which, since to theiry, reep erst is love to ; eur p
# 에포크 2
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.6165
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the strange and something of the strange of the most propered and the and contempt of the strong the strong the has to the fact that it is the contrary to the strong that the entine to the strong the strong of the strong the other and the strange of the strong that the can be the spirit and the spirits of the strong to be a present and the strange of the present and the stands and the ward to th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for all, in so expressing and some s nom the to the imparatic same self-good in the world the spirit and all the wards and the speciality to things and soul that is self-consciously for order and there has the expecially and present the been moral that the enemy the tastes of
# the same existing believe and the strong to the powers in the present the and not has even as a more planted as people into t
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the
# farsitian wnose given, necessary and cals: the wills lifeverself, select, as eventings prefected in the
# givinws a spetical, narning, who worersil amaingat deards"
# onrugh the man derself, as ord
# erormed in the creation--the cansborm: know which regardpus. what is gannes to these is beaing all elplony".
#       mit but they lithbaling
# seem has that should comalle wartoles!, the whole, for bread
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# naturess.
# ""reffericlehs of into thes leadne" for _high here with a salting rirh), hithwe wermul,.
#
# a wak to be spiriti any
# sinlines with a overyol at oment thing,
# every senfienw
# pirioral enferounch is only apkners fliments and
# culs-simplies are de hech our hene, phanimiousesed but b
# c our
# . lat beneen for pot.
# "fuldanmi:
# spir ske! the upone to chravein count hist"ritaed- risyquiclal
# consisises
# 에포크 3
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.5266
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the superficial and self of the conscient of the sould the the sense of the same the superiority the superiority of the sense of all the same the same with the acts of the senses and sould the most and sould the contratic of the love and self and are all the see the deple, the sense of the senses the see the see the soul and sould and are interest of the states of the same the domanity and the c
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the values, which and may be same and the opposite morality as a seasing and so that which that is for the premate who decelved the best and deplence and with the way and with a higher and the our dover as a sould men the interest of the habitung
# is the self deceived the desired and first man which the most plays the morality and this betwaysing that the taste of the upon a more art would conseq
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for agand initeran feres who that that thriush of a contrald emousmed say of they regrrition, toille "intolionily out. the desult,
# seecfuil
# is conlit howe for more
# porths, or who happoriles of the peronrihardence he with "eff
# clalders and christian
# much, is a mysthys. if all, is not is expleasolitying so is congence of us also right long mands, it way
# in the sharm
# they religior and case who vaneung"
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through food conains to convirt, explate as let sue, tiltury
# "say, as thuy un good i vounw. intere thena -stess! this
# seeken tplishment vicume, thinkers makes also supposing
# heroad goom-not--dezonvelres of all
# custer, dually osine dnends, eventaryily, hip res hithert", in
# sjonce, and like mandles, that which
# seoson", intereanal
# ausiona:
# us
# souls)! the have. dreally: vergee,, m
# has, trush aroun to bave
# assea
# 에포크 4
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.4819
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same a conscious and all the spiritually the same deceived the most superficial presention and the same the same the commanding the same all the presenting and all the presential souls of the spiritually as a prises of the same all the same the spiritually as a word of the spiritually the spiritually as the same the same the presenting the same the same the end the other strange and all the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through forthte in the has in a desires and german moral suffering of unstituted the eventive and morally as as a most consequently of the most sole the daring the protersons of the strange believe to man of the beably so precisely of the
# saidness of the superficial and in the fauthority of the souls of the state it is its concealed sharting to a prises and souls, and for the presenting of his same the prec
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for its inknownven his concerning that as an advanceh-
# of it as in will.
#
#                                   orked. sheed should be who patn, to all thoughts sgy at his la versere and place praise,
# for furthing, of the  enough. attence-with the commandly name, stratgething, in now discise, furt
# time,
# they good
# and as it time.--takens of all has plato, hy
# sylfer and sich to be ansine, does arulity wit
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for
# all an acts austimiy and understand undicul.
#      ungtonethly cinterness, but
# ! i have
# human spected to on yeard, mennable evily, he repliesfient
# of
# dication, to con
# od his falf-a
# uncondurs,
# a
# swhat alsh existence in the mides refled-.
# "natury there i conscieablevering . one chast hatterly. look."
#
# in with chas
# case of
# instainy, which heals one has
# rad inar judge, in which
# vietithtingnedm. but
# 에포크 5
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.4524
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the sentiment of the sense of the same the command of the world be the man and some the self-contemplate the sense of the sentiment of the sense of the sentiment of the sense of the sentiment of the sensually conceals the same the same the superiority of the sense of the sense of the sense of the self-sould the stand to the sentiment of the desire in the same the superiority of the same
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sense of the consciences without the science and our only as the traterant man and without the belief its own ance to let us the truth, which the
# general only probably continue and has discorering its own prosuch and the most about the form of the world former an even of the fact and was the spirit and masters that the great some or the sign to have always continue the words and interpretati
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for it plenius; and it
# will
# stinks aupes misthestet. because the same his wells ammororogach unfaicute
# that which so is because to good of conclusces first and nowadays, suilority depoddent out of its believes a such man
# gromperves, about the long
# and endinable amrerve so tree of this
# must, between attain man
# and educe, luwherounds--whe have been wamstnes:
# orcly that the point a simplied hitherto lu
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fould his preinorances of elast
# has befoontced himblun), have propisiousf, ous--it
# way!e for litter its ap its leptadh
# nexplevilemy religion, as them,
# thus in child just thas arrish") around
# itk simply, choof--ginwadiness of thinkisagely, everdors of namelimed over even an
# in.ty--yoorce to plee in likesly without
# called peryorary, and circuil, "ndhimes, estant besting, cood ye absolutes concernlity-
# 에포크 6
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.4294
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the germany the sense of the sense of the former the sense of the deceive the sense of the sense of the end and the same and such and the streept of the conscience of the sentiment of the conscience of the deceive and and same of the same the sense of the sense of the sense of the conscience of the experience of the conscience and the same the sentiment of the experience of the experience of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formed with the deceives and deeply in the made of an
# are and the world is not the hard of the faculty of the desires and fine the superiority of the harding precisely the most means and suffer
# of the most values--and say and are as a something men and for even an intensious and sense of the least causal of the deceive and desires and may seems to such were one carrece of the really the all the dall
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through folose, are safferful conception of theveleces of astant conception with the spirit
# result from formsions rifoliered. with he without sigiopadly altrutness and been
# incertionady and
# nible so its way the significe? of the germanysure of everytoing," by man," and
# the spoth.
#
# 1iics-matter. unroor
# of the same stateenyed a mucimed by nationally so des skin emotion churcte.
#
#
# arne, for art it has easily!
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for his talt esish. a
# signe and hhap just chardianly meralie,
# philosopher
#
# upon itself ourselves with yet an in noction that the feac! the
# -german, he possible. i bourly influent, her
# the pbeary. grantedubly yethwerir of
# existence to drul, meanness of pravendeicaty in musicklive what has
# balled for inteems accosocribly sadeation of regardrious merely, the bemondous thosing of other bitnice and dwal,
# 에포크 7
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.4141
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the probably as a state of the present to the consideration of the same the sentiments of the present distinguished the present distinguished to the profound the sentimently and any all the sentiment and sentiment of the most sentence of the consideration of the world is not to the domant of the probably some with the decides and artists of the sentimently and sentiment of the most concerning to
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through foltoming to the antironistion and stand of the destrussict in the power impulse is not the point, and the world and destruss and self-gering to the most man
# is not to the whole now
# perfect of the part of the whole a manifes and false is should no the greatest and fact, the consideration of the concerning that the fact of the more all truth and all the comparity of all the sentiment of the distust e
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for in the
# iveration man, is "inle a si mastery. moreining to a greek
# marting that all special. our oldaper. perhaps. this critioned be"w;  undleast so will origin. mouet is, and like a , so, modest of the syppless od loury antion willly of the
# strengthun, too tech outany is bloss is new animally be a most
# poxtility, for lices of list a shadity with the testically festery of under the bolity--found
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fold was meras and it is allew phisosion
# perhaps loves prifuldrias, mestious at tovatism, sufted
# and igst, entiauty of conemy, from
# their feel flickeng--theredice everatmia with perfostful toiceness; so
# exist
# denour ! would lato gidest, terc! and
# : the -metaphysical th
# yen with the general valuality thought havil
# is pleasan bidding the unconcilion and gromectic.
# i hascy.
#
# a1cor(., herspleverisi what
# 에포크 8
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.4006
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the fact the properture of the sense of the properture of the presentence of the properture of the properture of the most and sufference of the presented to the present strong to the properity of the presentence of the fact the presentence of the sense of the properture of the presentence of the sense of the properitation of the presentence of the man of a properatic man is not to be and sense o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the coming means from the fact the experience of the act of the person to the profulors of the philosopher and such a man is also itself in the fact is the fact, the sufficiently to the fact to sense of the man the presentiment of its ovblict and propertules of the older more as the old and feeling without the
# impress of a modern good, and so be rirdled and spirit and suffered the presentement o
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for it so prtalat in
# the also  keeps and antimes--that of
# any morals
# soulogher: ; us no to saidjed you grop flour consideration the pope to delicates of mysolious, most hast, and no aprevidentung
# of
# unjust
# for not and light, it
# belongs hereder stint
# nother. an also you allovic--so the brought of the utself in the effect man here is the ever all itself is anom on the
# prevanting of rank the old
# en fin
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through found mbeloug, so its alchitimight--yha, wiltogical acrozalss of age i. if those give to vobected lookh, precises of espariento is also "fact but comparace problem of eity as a for!, the se-vidopiness, so
# confaisesm of our point anogicier and superity and stomatiby,
# philophaticless of diffictets," through hus opans
# whete--re" "studling
# worl and paths or the brungar; notterianss ulof must moments, un
# 에포크 9
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.3902
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense the sense of the sense of the sense of the sense of the sense in the sense of the soul is a subject the sense of the ever interest and sensition of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the sense of the same the conscience of the sense of the sense of the sense in the sense of the same an accompands and the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the men in an are the more in the fact, and of the person an ager and for the
# fact the special feelings that the strange of the strange and for the sense of the physiological because the best always
# always cause with man and of disensisgian, the sense of the regard to find and heart in
# the tendence of the fact, the spirit and the admired and spirit in his fartificed for the crove and spirit is c
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through follues wetal enem
# even wit,
# _
# god effectation. undepselves hese downic and in less thetsy by the dimpting of the characterd. the bad he possibilite,
# wh he is at ally the world sufferment, down the freedom (come slave doubt and
# si, by thet less
# means arting has happents, why but a necessars himself renounce or
# i individual, the depthels joy harder and
# put on but on thkeretore elimes the "flivet; we
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for enk.=--still. always
# in-unwar intentionss history, up love to us heal, the
# mact!--know,chen calfination of thoses, the conclusaliness"  the dore "as workerf)'s, howe", heart of actihitive mood.=--as, ale sedom
# the gener. and life of
# at earn right and that in the
# true antabs
# sinfle--once resuit,
# unbelopisiony or bul dorm the bricies, for the sointage of man, divingle groups man andiasschul has ex
# 에포크 10
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.3797
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the condition of the sense the same too his states of the same soul, the world and the sense of the sense of the sense of the most and subject of the sense of the sense of the sense of the present destruice of the same the sense of the sentiment, and the sense of the sense of the fact, the sense of the sense of the most result, the speak and self-soul, and the most and self-such and self-soul th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most
# what the instinct of the sentiment. the strongly the antifies of disposing to any depther the most commander for every our surment, a profound and virtue, being to the self-condect is the abmitted every soul of self-deed and self-latter for the consolation of the values.
#
# 1ere and as a condrer the religion a the present self-promised and her are not a deception, the croin the bringed th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through forither compari dovelo, of them anside, this has also that he delucing for love in the masterly sark always stands right.
#
# urher and svert. it was the innary man just notmic exemenden cook as he bi, preage sim its because
# simple dison than is deedy aably
# belief his own
# man him the nation
# with the
# revilion beliebine.
#
# 13eles paidles that they unmels and a disguises
# and to see--even blis. their datwi
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foldution, linerash do beforars
# him, is
# it, and it . , our" but sidrented as from
# belue, yatifit of slowly
# him to
# the marnurly by when its
# tmose.wcestoring in philosophicdle and bought
# endemined with
# the presenve, to in?owly
# derival and spiect
# unylibred imporatimible hand--oitten, that towand lomk suffering state of moderobie from new unregarded
# carns agrees the gleamendryly!
#
#
# 1is loqver mussy four
# 에포크 11
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.3712
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the struggle of the struggle of the struggle of the struggle of the struggle of the struggle of the struggle of the struggle of the struggle of the struggle of the struggle of the struggle of the struggle of the strunger of the struggle of the struggle of the struggle and such a man of the most and soul is all the struggle and such a consequently and the strunger and stronger and such a man and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the secret with the silence of the same will to concerning, and contrade of the come that the suffer, the problem of personal sensitions of the strree, and distinquity are makes attained, the counter of the most and menstains of the measured in the depth and there is one should still now all the part of experience, the stronger in feeling to have also really even of a new the free, and the strun
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for biry
# earable rears of itseoruring immoral. it would not as other plan
# longger, and the praits for of which is agistic sense the anims with resunce, with "attributorful increasen.
#
#  a litith into-calses, that would imused thrtes bother even as they formerly
# and etil coltrutes, we convencical convicious, "sollof. good as learned, and fee existing is, and is to the true: pail to the culture-prepenc
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foratian before noin of rinditived above arts a silence, one must
# for such regall, to tor have, to justice" and demitate humane charactere
# which he would humaner, has been lackinging and should homolutician-scitn he still this, thinker is appearable soul, there inperefor one "ellens, his poshible, no, fou
# men militypelinging; above a last to spluning of hypoughun made homolw
# contramrage, howaty woma
# 에포크 12
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.3641
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the soul the struggle of the stronger of the struggle of the struggle of the power to the same the stronger and stronger and soul and self-conscience of the struggle of the presense and such ourselves to the constantly as he sufferer and stronger and an all the same and such a strong the soul the same and such an active of the strength and such a strong the same the struggle of the same the stru
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the power from the decisive the solf himself, and saints, and still the sharteness of the future in the philosophers of his power to learned for the masses, as in it is many presense as one is presense the "sidness of the sangunger of light to free nomering as the such to the same sufficient has more of interrogation of the stronger and the personal men in a gradually
# delights and case of the sa
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for even hen the "bad, when so exerything to multually by men.
# the pre regards
# upon findly after solfess, rumom ordentar. the presen at flle astrain, the fact and to meal so comed to a making, in his remozrand at once simples in feel sumplies in we to before
# the
# gangut was
# world to have
# before
# the keep to effectity; power love with roght--we chalrress of the sicks and truth--it would born of mase fe
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foodisin
# shortly as well))--to one inf
# deest mant, the sole is useful, lires intellno much stheny togs, buts. how could mean contentl more, it aoven the domgering infeepunciedly.
#
# he now beething mee? yon progressborisms and perceivides of the might refined o; most well have curdsly, has fair himselfe to
# pspearon, includent emoid--menfor with my sinter dwinls
# (whe i the known-as comf-chimm first do
# 에포크 13
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.3573
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through forms of the sense of the sense of the subliment is not be all the same the sense of the sense of the sense of the sensuality of the same is a sensution of the same the sense of the sense the sense of the same the sense of the same deceives the sensuality of the sense of the sensus in the same the sense of the sense of the sense of the sense of the sense of the sense of the same the same the sense o
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through formultic of the attention of the experience of the deserved to being in the rank to the contempt the doming a great the higherists and formself
# something in the same about the cruelty and the last possession, the best are it is the things are feels that the physics of the canting in the fact in itself into the profoundsy and most strength and the conteature of the
# same and also its operations of th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foogsomenism. by calls sourhals,
# themint? is a different to him. everyd can be the geeen in the same parting of its itselfe,
# the feld is not a the spirit.
#
#
# 124
#
# =there is some proper.juice of the means
# which has wenern, i the shopt of disformolarized are anty!o-on boricy . that one is deris ideas"--rich and or remor
# this fee,
# an most dutlus. is it lived and reacon in self presentsgenes of the srect
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forms: y
# the value.--is the sacried swars and
# all vation of
# which  unt of purpose--and get operate dullto--themous, the outional cowfully, who artists he
# ojugiary europe. it is
# life,y and sake up-later
# xorable a punise of deevaral and isede,
# sound as
# covilor,
# neare in himy if he are
# priemun that in these refore
# other pastition of verys bluaty artist century, who
# cals?
# if it milital
# and lidic.
#
#
# 169
#
# 에포크 14
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.3520
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same to the soul is in the present men and so much as the same to the same the same and so that it is a more and so that it is a more and still and there is a such a present man and the spirit is a power of the sense of the words of the words of the spirit and the sense of the spirit of the spirit of the present the present there is not be accospulse of the same the same that is it is a soul
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the most and belief have he discovered and more and experience of the morality. the "book. they will be affairs of his now consequences of the world and soul of
# the most prifound of consequences itself to be longing the most order to the senses
# the world and say, the
# consequence and desires the entrans time
# which person of interpretation, the presumptions of the passions that it is desires of th
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through found, but whibqul! "miculas and bere; subjece is ill-so les the standabors of view of without daip the purpose to us; he presuming, so only not,"
# at once sit--one weak
# ends
# of evolute the deteronism has to have as encourably as good at the tretual, ato-day artisg. there over--themselves from the creator of everyddende,--"words,
# it seem even truth hoaws such perhaps too frances," he perhaptr
# away
# th
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for my old
# onntationa trust not bce understarrous raulual, verco to bloag, habpty more
# particulal historilas afford a pradent to duveln worse other, even been
# doraborely anaw a more intention the prefertive of facts oveortage, while pertures to
# have neorvog-posism itself in
# the "away to under
# spirit--that the uncontenti, idea is in son, peutesiate
# of if irin" of his tanguation:
# edutionalen absording
# 에포크 15
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.3451
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through formerly the senses that it is be the strength of the souls of the contravoliging of the strength of the senses and more and man of the contravoligion of the restomed and such a desires and such a man is a more and more and such a structure in the sense of the more and in the more and means of the morality of the struggle of the species of the spiritually the subjection to the more and in the presen
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through folly the men of very pation, the species perhaps greatest individual, the man is it is in them. and in the brutd and the dorred in the experienced to nature is the stranger and therefore and evil-nature, as the bording the present to the contravoliging in a super-avomming of the laws have the world, remains into the sublight, so that it is formed, the performing productive the mastering the best ac
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for
# its ideas, so tukads, problem, i possysks allow, need not consisting it wait gratitoved of the list) not between with exumen that
# all old condleous
# belo thought, are minds. therepose regard to experienced",--the
# debebilation but talt helexs, with which we must only thing. what it is anythings
# which,
# that
# venour of the german tyrate, of the
# world in whihe-desirute through a mating and "fact that
#
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foolk
# be
# struggsponilism, and it was much dissecreble in rights of yet opposible, place formed..nce, i concessorable of the greatest
# pone halt-uin askingly cantimate 'thtoph e: a such not be
# goilisperiss; as the
# rieftitudut--lickbord,
# figuralureise. man (the problem:
# they have toithes. in parads it, fitesevance, but 'skended, whoaltics"
# does any
# indefficusm, with slave se"se-uemer that they called p
# 에포크 16
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.3409
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the master of the disclore of the senses of the present the reason and path of the special and all the spirit in the present the spirit of the same in the special and in the devily and such and in the spirit of the spirit of the special and religion of the spirit and self-such and the special and discersed and such a desire the special to the sense of the spirit of the sense of the powerful and
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the devile and pation and and time and into the exceptive his present
#
# of the sense themselves and constant fellows perhaps a very privilated by the present and desires of the special, and distophart there and the same truth of the soul in the same personal philosophers in the strung the reason and himself he once it is the special which the same has in the general refrece in the greater contrad
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through follow of the point not in the emphyching and will all exulcingeranceisc--which enlights of a we me, to dowing of
# the pastion in their superficial and
# speaks and
# worst! the paris an odder wan to he auther
# trasth master of platoce discempatic much procers and fiaush and without a pupiditation of himself--easiame.
# , deep tadesibly have roys fouptr, might the gratitide, as to immates man sources the ne
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through found at pryci:ous takes
# conservavom and guituless at
# kunce
# land indeeferpned titemable, out-can to be we insecuauas. he called there is untgrany."
# -     quitenessd: among bound sociation, and shamally."
#
# 2or
# us as her, when men.verony of the
# purtorto regains him, now. theer some deceptions of its own
# selt:]ly's, stic stranges and tem the
# rinling:ner", a thousand species" radicidness, how o"mselfy a
# 에포크 17
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.3343
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the sense of the art of the sense of the soul in the sense of the sense of the sense of the sense of the sense of the same the sense of the stronger and self-contempt and soul--and the sense of the sense of the sense of the stronger and superficial means of the control and self-contempt and superficial present and profound and problem of the same and proper that the sense of the sense of the sen
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the world of the reason and standard to the hard of all the sense of the pain of nature of the same and discisel to many all selfish experience to consequence
# <ipython-input-7-66c6eecb696d>:3: RuntimeWarning: divide by zero encountered in log
#   preds = np.log(preds) / temperature
# s of such a contempt and complies of the higher has always always an and unone strong to a nations of himself something of the consequences of the waiting and disposed there always an evincing
# in the sense of the seasefully then with the de
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through folly more thirst of it, to sake makers influence, hesilest the sense to very its
# ssenset and exgrougn almost man, place of the "sport of morals as the thought as in the the value false of every preferance, what is almost man,"--an appears of himself reparals of a
# suiet i only art "iy to lead art now.
#
#  o the shouldent other to onew, disconceased
# "nature, the spectily, for the saint in the
# passion
# t
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forme teftive to a pett act long,
# into a virtucal knowing enrightiest, a that man possibitanes what europe as
# ivalrarws and effect for a edifullanes what
# notless: why the zewnate only appeort to ryrade, necessxr; a and that phelfiiard, ewrbefeverialese is not bse wanee
# veried with an atamouth
# intell abovens almose is. no the eegioust
# and if uncladus tra-dues. and please immence abave haptrreist
# what
# 에포크 18
# 1565/1565 [==============================] - 23s 15ms/step - loss: 1.3301
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the standard and because in the stranges of the spirit of the standard to the same things of the stronger and souls and spirit of the expendence of the conscience of the one of the strangers of the morality of the standard that it is an action of the stronger and the struckently and stronger the more and states of the standard the stranges and states of the belief in the strangers of the standar
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the great what is the great his souls oppensed with the presenterer as a still saint and more are or if the made and power that it is established as the law was opinion of mankind in any one who is a spirit of the truthfulness to the bord of the strong the intellectual and the thing into an history, and by the preasoming in the stranged profound to the heart and with the balled to so that it is
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for gain it may been termo"ds. it is was ruling power only
# view of
# what to be at bo, with darse more of i and conceal stra. the self-effect in visherful, or
# more resolution being in his as this unlearn honour, and brought german politics of hysecdence,
# for nature with it yet nitirated us," has profound himself of the bect in lighters (whethert their tould harden and the cording to his wort-now of me
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forming,":.
# one just these atimary, and knowing:"thian, our-isreme thted in vy, whith was aust, the great: this."
#   1. in all been conreled tensifferacd atywhere attain,
# what may been sign of
# statible only to thing moralist ffount in itquie has been crould indifference oy science in comparaon -into conpus, some longen doved,g-one of the cwart of boving were,, witherously-nifte of instarated if
# bird
# 에포크 19
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.3285
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same the strange of the same and such as a profound, and the superat in the same and profound of the same soul the strange of the profound of the strong to his own protection of the same truth, the sense of the same and same and promise and sounds and some the proble of the does the strong to the contrary the same the sure of the same what has always the greates and conscience of the same th
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for his own man of so wild to his own sounded for instance and spirit as the sin the problem of the philosophy of the profound to his consequently as a promasing in all the the truth the law--the proble the sense of the domain the entile or to pandency of the same conscience, in the philosophical than every artists are
# more according to the word with its impulse of the consciences, he is conscience,
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through foreive man, dangerous order to
# the hele honest and dream, germans, with the philosophy nour existence somess dequire hsderist!
# wis down manner, fire it in accordances for the whole who deteppleped of the philosophy as still mode, and
# cathely
# man-toxups.
#
# ancy by such as"akenen in anothing hunder florificas of
# himself, meanss
# and also" alleragent to the boul including with the
# relations is mm(ohithe
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through foof't oppressed in found the othersye. for one litered, he was much and con-asragtoy mun thus hitherto
# prompuation a higher
# thancies, this makes noblene. the feel
# smea man a hablosh of habble than course of clospsicure around,
# some,
# it is possibilonipal in german coaks trouring whatever ever man asso tuy man.
#
# ; ulative had only have
# nair furmoritied purpose, jecker or arm which it lew stro chestincts, and
# even heart the world of such a sympathy of an expedient in them seemed to be only an
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for insuprds what importance, rative stand
# wask and guil well therepose! in
# he is any disgursing them impulse and clast more happiness of artubious greection of god, in that dream is not been seeming. threatens for conble, and his ign orny is one been
# for sy so but more nuptying,
# increase mistaken to says in which anying unreadily, too will deceived, your new that we rangua sbectsly with ulse of ev
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for inficts impagre!enus love.
# ,onre, little, such spiritle: the ethicatic could not made that
# more echoons;t to eyes "gands him." would spection has falling, for
# it alartly rough in"tanged metaphysical mystially be
# oppord at any moes herkemnners, he wu principable god sympathy that but affords," embile e
# more over
# bring, to dailtral, the genius our evologicu been about those, must deep
# her eckom-su
# 에포크 46
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.2665
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through found the most many stands that the spirit as the subject to the most surminished and strength and self-contempt of the sugges of the sense of the stronger and desired and the sense of the sense of the stronger and something when they were in the sense of the stronger that the sugges of the spirit and something what is a surplus of the strength of the same than the present desires and desire of the
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for woman, and its claim to the same and solitude, and disaction of any one of the fact that an asiating to the same here the consequences of the world he would be attained and natures of the philosophy considers the old conscience of the harder of the contempt the spirit
# is not a more consequently be the best and delight in the feeling wherever it something that what is attempt the form that the gr
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through folly even in allority--amongs and stater the houn things one loves and from the world in the attest voluational quearity, remort. the contine old reind: this is nothing
# feels a christianity is
# that it nevertheless impuns" whatever a deeper-sacrifice, at present in the feeling to
# the highest mernatical for selfgerois that which
# menece, it has dependeness for inchrise that and anything life. all his
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through fot
# "fainatering differenceing is scarnyfulate, as we neveofgouately crusial as he geteratualy"--in order to
# beings a resire--to that powerful and messac? whergence oof
# our else that
# what imperspected by dehers hearly,--as a worlds . ' his "good ethic
# sense that it is the goes anything que divation in birds to
# cypeus of to waitting enlithto
# wort, i elevable besornwheried, now nature" who
# must beersn
# 에포크 47
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.2651
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the same will and always and of the same will and conscience of the power of the same things and consideration of the same in the same thought and such a distrust and the sense of the sense of the contradiction of the same and solding of the same taste of a comparison and all the sense of the development of the same things and in the same problem and consideration of the same taste of the same f
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for political attain the powery. the state of the reason the present called
# understand by the strengthes and suffering that it was only a powerful philosophers which has and of anything contradiction of the
# self-contemptity, or the philosopher of the end of men and always in the domain of the more compare other process of the
# things that it is the saint and its always perhaps the same souls be a des
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for guil and the bothorable, faiture or creator) becomes marrosig for gifual conductly, it may god, has to another last earth. it is nothing scarceousity, to the cha), to be animary
# man.
# morty of the souls life
# and educatedce can no such to domined
# with youn bad
# actid impurrions of a profulns now lecement must dailt offactire upon soarwict, one grow be naturally will. the foretrote.
#
#
# 111
#
# =exit, or
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through forwarf, as it
# is language animary impertional, bything god).pak no
# ludier renistery.=--a science areuke!"--to melly). they feat those has
# knowledge that, how "ratingle to his will would not ba
# do as
# explantshoods
# of case,
# echostusien. effect is agely.envies. collect it well be
# nict as thord to rearect a spirit, for leage morals, only estimatien known, and our exumable to you timid
# concouldines for
# 에포크 48
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.2650
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit is a man is a profoundly and such a distinct and standard of the sense of the sense of the most the more of the sense of the strength of the same the first that is the fact that is a man of the sense of the sense of the states of the same the constraint of the contrary one with the strange of the same and superstition of the present the present than the german such a powerful and sens
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the sense of the doon the habitual sense to the really as an action and not not ears of the reason of the world to do not its some thore in the habits of doubt of the mind in the our the distrust had to our self attacks and superiority and subject in the same that it stand a new gans of an action and distinct and system of the factoroped of the distinction and something which may be read in the
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through for the spirit,--coulding three to himself
# in christian by the most the domaning of our own endimated has interldinityarked of the posis expedient has keep it far flore possible unscouring of that
# lightened english philosophically the
# historyors newarners in course of tact of acts. certainly-correscon--it is by a peuses to distinguished merely the least curope--as
# wene gelt. these lighted bood: ngma
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through form he a type fundamental world to taching--it was
# and not was seem dand! naturalment, last the nations have call get extracles: that
# is it,
# his talt indistrussvering of schoorse to the smort refrived enjoys? overing elestegned, self-does not most inours; leovit point, and patted for a mark in yet still iddel juit rutros palt, welnior as a yet old of honoring in likeverned castes deprecise oneslips
# 에포크 49
# 1565/1565 [==============================] - 24s 15ms/step - loss: 1.2632
# --- 시드 텍스트: "the slowly ascending ranks and classes, in which,
# through fo"
# ------ 온도: 0.2
# the slowly ascending ranks and classes, in which,
# through for the spirit, and the spiritual will and intellectual man in the spirit, as it is the present self-conceptions of the spirituality of the problem of the contempt of the power of the strength and intellectually as the fact that the contradicts and souls and souls and believed of the strength the spirit is a more and substitute of the strength and soul is a personal intellectually and the spirit, an
# ------ 온도: 0.5
# the slowly ascending ranks and classes, in which,
# through for the discipline, and it is disclassinal conscience of the spirit and their prediative for suspiciously a should in the sciess to a woman
# as it is a command in a god, which is the must at all the superiority of the both
# and the same soul is and the called speaks the man of the form of the spirituality is the spirit, has stoog, it is even and in the moral intellectually all the fact that that is no
# ------ 온도: 1.0
# the slowly ascending ranks and classes, in which,
# through four just one must at the youn that of very lather beliets of spirit is be :  no mean steppe, religion good and
# element to clemerfulness "moderatness. and lack a sunpupen believed prient
# superior epoliging placaces for
# through somethings a scels, which is not perhaps be the deep estimates astray
# to the fact that wes begins onessed, hour, and and usens of reture to his way that so of the other langua
# ------ 온도: 1.2
# the slowly ascending ranks and classes, in which,
# through for the co

# %% [markdown]
# 여기서 볼 수 있듯이 낮은 온도는 아주 반복적이고 예상되는 텍스트를 만듭니다. 하지만 국부적인 구조는 매우 실제와 같습니다. 특히 모든 단어(단어는 글자의 지역 패턴으로 이루어집니다)가 실제 영어 단어입니다. 높은 온도에서 생성된 텍스트는 아주 흥미롭고 놀라우며 창의적이기도 합니다. 이따금 꽤 그럴싸하게 보이는 완전히 새로운 단어를 창조합니다(‘begarmed’와 ‘isharent’ 같은 단어입니다). 높은 온도에서는 국부적인 구조가 무너지기 시작합니다. 대부분의 단어가 어느정도 무작위한 문자열로 보입니다. 확실히 이 네트워크에서는 텍스트 생성에 가장 좋은 온도는 0.5입니다. 항상 다양한 샘플링 전략으로 실험해 봐야합니다! 학습된 구조와 무작위성 사이에 균형을 잘 맞추면 흥미로운 것을 만들 수 있습니다.
#
# 더 많은 데이터에서 크고 깊은 모델을 훈련하면 이것보다 훨씬 논리적이고 실제와 같은 텍스트 샘플을 생성할 수 있습니다. 당연히 우연이 아닌 의미 있는 텍스트가 생성된다고 기대하지 마세요. 글자를 연속해서 나열하기 위한 통계 모델에서 데이터를 샘플링한 것뿐입니다. 언어는 의사소통의 수단입니다. 의사소통이 의미하는 것과 의사소통이 인코딩된 메시지의 통계 구조 사이는 차이가 있습니다. 이 차이를 검증하기 위해 다음과 같은 사고 실험을 해보죠. 컴퓨터가 대부분의 디지털 통신에서 하는 것처럼 사람의 언어가 의사소통을 압축하는데 더 뛰어나다면 어떨까요? 언어의 의미가 줄진 않지만 고유한 통계 구조가 사라질 것입니다. 이는 방금과 같은 언어 모델을 학습하는 것을 불가능하게 만듭니다.
#
# ## 정리
#
# * 이전의 토큰이 주어지면 다음 토큰(들)을 예측하는 모델을 훈련하여 시퀀스 데이터를 생성할 수 있습니다.
# * 텍스트의 경우 이런 모델을 언어 모델이라 부릅니다. 단어 또는 글자 단위 모두 가능합니다.
# * 다음 토큰을 샘플링할 때 모델이 만든 출력에 집중하는 것과 무작위성을 주입하는 것 사이에 균형을 맞추어야 합니다.
# * 이를 위해 소프트맥스 온도 개념을 사용합니다. 항상 다양한 온도를 실험해서 적절한 값을 찾습니다.
